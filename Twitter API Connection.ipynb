# %%
import re
import pprint
import config
from tweepy import OAuthHandler
from textblob import TextBlob
import tweepy
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
result = api.search(['covid','Covid-19','COVID-19'], lang='en', count=10)

# %%
print(result)
# Out:
# [Status(_api=<tweepy.api.API object at 0x00000171B17EC888>, _json={'created_at': 'Sat Aug 28 18:23:39 +0000 2021', 'id': 1431683916147068928, 'id_str': '1431683916147068928', 'text': 'RT @DWUhlfelderLaw: 5,822 Floridians have reportedly died from COVID-19 since Ron DeSantis\'s PAC started selling "Don\'t Fauci My Florida" c…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'DWUhlfelderLaw', 'name': 'Daniel Uhlfelder', 'id': 1011970623470489601, 'id_str': '1011970623470489601', 'indices': [3, 18]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 160248519, 'id_str': '160248519', 'name': 'PerSueTheDreamNow', 'screen_name': 'suevess', 'location': 'Nevada', 'description': "I'm in a new phase of life, retirement. And that means following my OWN dream Right now that dream is to live and travel full time.", 'url': 'https://t.co/Cg0lyjWg1Q', 'entities': {'url': {'urls': [{'url': 'https://t.co/Cg0lyjWg1Q', 'expanded_url': 'https://www.youtube.com/channel/UC1cts6J-YjafpAv6LeeG7wg/videos', 'display_url': 'youtube.com/channel/UC1cts…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 341, 'friends_count': 228, 'listed_count': 7, 'created_at': 'Sun Jun 27 16:45:36 +0000 2010', 'favourites_count': 110946, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 33986, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/707763789437886465/yzbsEw0B_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/707763789437886465/yzbsEw0B_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/160248519/1457578920', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Aug 28 14:21:23 +0000 2021', 'id': 1431622947358318594, 'id_str': '1431622947358318594', 'text': '5,822 Floridians have reportedly died from COVID-19 since Ron DeSantis\'s PAC started selling "Don\'t Fauci My Florid… https://t.co/06hdZ9jIk1', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/06hdZ9jIk1', 'expanded_url': 'https://twitter.com/i/web/status/1431622947358318594', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1011970623470489601, 'id_str': '1011970623470489601', 'name': 'Daniel Uhlfelder', 'screen_name': 'DWUhlfelderLaw', 'location': 'Santa Rosa Beach, FL', 'description': 'Husband, Dad, lawyer, entrepreneur, @Stanford & @UFLaw grad, Florida Grim Reaper, Justice & public health advocate & founder ...

# %%
pprint(result[4].entities['hashtags'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-bb8082d76987> in <module>
# ----> 1 pprint(result[4].entities['hashtags'])
#
# TypeError: 'module' object is not callable
