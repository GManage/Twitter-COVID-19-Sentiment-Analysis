# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt 
import string
import emoji
import nltk
from textblob import TextBlob
nltk.download('words')
words = set(nltk.corpus.words.words())
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
# ML Libraries
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.svm import LinearSVC, SVC
from nltk.classify import NaiveBayesClassifier, MaxentClassifier, SklearnClassifier

# Global Parameters
#stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package words to /Users/jtangesq/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
df = pd.read_csv('../Resources/covid_vaccine_090721.csv',encoding = 'ISO-8859-1') #Dataset from Twitter API
df.head()
# Out:
#                                         user_name  \
# 0  NSW Multicultural Health Communication Service
# 1                               Climate Detective
# 2                                    david sirias
# 3                                      COVID News
# 4                       gain-of-function research
#
#                     user_location  \
# 0                             NaN
# 1                             NaN
# 2               Port Townsend, WA
# 3                  Estados Unidos
# 4  Undr the pine hunting lobsters
#
#                                     user_description         user_created  \
# 0  Official account for NSW Multicultural Health ...  2018-08-20 02:00:05
# 1  Physicist (MA & PhD) & socialist exploring cli...  2020-11-07 17:03:33
# 2  Lefty songwriter/musician/producer/publisher. ...  2011-10-28 20:14:55
# 3                                News about COVID-19  2013-06-05 08:52:31
# 4  @Ayjchan's mandate: 'ONLY look @ a -Leak- frm ...  2013-12-24 20:30:14
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0            1277           243             2311           True
# 1              94           155              354          False
# 2            1262          1115              489          False
# 3            3330          1472              130          False
# 4             272            20            24001          False
#
#                   date                                               text  \
# 0  2021-09-06 23:55:48  âPlease get vaccinated. Take COVID seriously...
# 1  2021-09-06 23:46:16  @apsmunro That is a lot more than the risk fro...
# 2  2021-09-06 23:38:34  As I said months ago, anyone supporting a blan...
# 3  2021-09-06 23:36:50  More crazy Chiropractors!!! This time in Flori...
# 4  2021-09-06 23:29:20  Great 18 point case about why you should not t...
#
#                                             hashtags               source  \
# 0                                                NaN            TweetDeck
# 1                                   ['CovidVaccine']      Twitter Web App
# 2  ['FascistEmployerMandate', 'FascistVaccinePass...     Twitter for iPad
# 3                                                NaN    Revive Social App
# 4               ['CovidVaccine', 'COVIDVaccination']  Twitter for Android
#
#    is_retweet
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %%
n_df = df.drop(columns = ['user_name', 'user_location','user_description','user_created',
                         'user_followers','user_friends','user_favourites','source','is_retweet'], axis = 1)
n_df
# Out:
#       user_verified                 date  \
# 0              True  2021-09-06 23:55:48
# 1             False  2021-09-06 23:46:16
# 2             False  2021-09-06 23:38:34
# 3             False  2021-09-06 23:36:50
# 4             False  2021-09-06 23:29:20
# ...             ...                  ...
# 5674          False  2021-09-01 00:04:20
# 5675          False  2021-09-01 00:02:26
# 5676          False  2021-09-01 00:02:16
# 5677          False  2021-09-01 00:00:41
# 5678          False  2021-09-01 00:00:00
#
#                                                    text  \
# 0     âPlease get vaccinated. Take COVID seriously...
# 1     @apsmunro That is a lot more than the risk fro...
# 2     As I said months ago, anyone supporting a blan...
# 3     More crazy Chiropractors!!! This time in Flori...
# 4     Great 18 point case about why you should not t...
# ...                                                 ...
# 5674  Excellent summary of where we are headed as a ...
# 5675  @krispykreme is #sweetening its #COVIDvaccine ...
# 5676  #CovidVaccine Does not work.. https://t.co/Xoi...
# 5677  We are excited to be soaring together again, b...
# 5678  Beth &amp; Stainy cover the complexities of va...
#
#                                                hashtags
# 0                                                   NaN
# 1                                      ['CovidVaccine']
# 2     ['FascistEmployerMandate', 'FascistVaccinePass...
# 3                                                   NaN
# 4                  ['CovidVaccine', 'COVIDVaccination']
# ...                                                 ...
# 5674                                                NaN
# 5675                     ['sweetening', 'COVIDvaccine']
# 5676                                   ['CovidVaccine']
# 5677                                                NaN
# 5678                                                NaN
#
# [5679 rows x 4 columns]

# %%
#regex the hashtags 
#n_df['hashtags'] = n_df['hashtags'].apply(lambda x: re.sub('\[.*?\]',' ', str(x)))
n_df['hashtags'] = n_df['hashtags'].str.replace("[^a-zA-Z#]", " ")
n_df.head()
# Out:
# /Users/jtangesq/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
#    user_verified                 date  \
# 0           True  2021-09-06 23:55:48
# 1          False  2021-09-06 23:46:16
# 2          False  2021-09-06 23:38:34
# 3          False  2021-09-06 23:36:50
# 4          False  2021-09-06 23:29:20
#
#                                                 text  \
# 0  âPlease get vaccinated. Take COVID seriously...
# 1  @apsmunro That is a lot more than the risk fro...
# 2  As I said months ago, anyone supporting a blan...
# 3  More crazy Chiropractors!!! This time in Flori...
# 4  Great 18 point case about why you should not t...
#
#                                             hashtags
# 0                                                NaN
# 1                                     CovidVaccine
# 2    FascistEmployerMandate    FascistVaccinePass...
# 3                                                NaN
# 4                 CovidVaccine    COVIDVaccination

# %%
def cleaner(tweet):
    tweet = re.sub("@[A-Za-z0-9]+","",tweet) #Remove @ sign
    tweet = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", tweet) #Remove http links
    tweet = " ".join(tweet.split())
    tweet = ''.join(c for c in tweet if c not in emoji.UNICODE_EMOJI) #Remove Emojis
    tweet = tweet.replace("#", "").replace("_", " ") #Remove hashtag sign but keep the text
    tweet = " ".join(w for w in nltk.wordpunct_tokenize(tweet) \
         if w.lower() in words or not w.isalpha())
    return tweet
n_df['text'] = n_df['text'].map(lambda x: cleaner(x))
#n_df.to_csv('') #specify location

# %%
#remove short words less than three letters 
n_df['text'] = n_df['text'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))
#lower case all texts
n_df['text']=n_df["text"].str.lower()

# %%
tokenized_tweets = n_df['text'].apply(lambda x: x.split())
tokenized_tweets.head()
# Out:
# 0         [please, take, covid, seriously, joke, from]
# 1    [that, more, than, risk, from, risk, from, vac...
# 2                  [said, anyone, supporting, blanket]
# 3    [more, crazy, this, time, where, medical, doct...
# 4            [great, point, case, about, should, take]
# Name: text, dtype: object

# %%
#Stemming is a rule-based process of stripping the suffixes (“ing”, “ly”, “es”, “s” etc) from a word. 
#For example, For example – “play”, “player”, “played”, “plays” and “playing” are the different variations of the word – “play”.
stemmer = PorterStemmer()

tokenized_tweets = tokenized_tweets.apply(lambda x: [stemmer.stem(i) for i in x]) # stemming
tokenized_tweets.head()
# Out:
# 0            [pleas, take, covid, serious, joke, from]
# 1    [that, more, than, risk, from, risk, from, vac...
# 2                      [said, anyon, support, blanket]
# 3    [more, crazi, thi, time, where, medic, doctor,...
# 4            [great, point, case, about, should, take]
# Name: text, dtype: object

# %%
for i in range(len(tokenized_tweets)):
    tokenized_tweets[i] = ' '.join(tokenized_tweets[i])

n_df['tokenized']= tokenized_tweets

# %%
n_df.head()
# Out:
#    user_verified                 date  \
# 0           True  2021-09-06 23:55:48
# 1          False  2021-09-06 23:46:16
# 2          False  2021-09-06 23:38:34
# 3          False  2021-09-06 23:36:50
# 4          False  2021-09-06 23:29:20
#
#                                                 text  \
# 0              please take covid seriously joke from
# 1  that more than risk from risk from vaccine pos...
# 2                     said anyone supporting blanket
# 3  more crazy this time where medical doctor writ...
# 4                 great point case about should take
#
#                                             hashtags  \
# 0                                                NaN
# 1                                     CovidVaccine
# 2    FascistEmployerMandate    FascistVaccinePass...
# 3                                                NaN
# 4                 CovidVaccine    COVIDVaccination
#
#                                            tokenized
# 0                 pleas take covid serious joke from
# 1  that more than risk from risk from vaccin possibl
# 2                         said anyon support blanket
# 3  more crazi thi time where medic doctor write mask
# 4                 great point case about should take

# %%
all_words = ' '.join([text for text in n_df['text']])
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
n_df['polarity'] = n_df['text'].apply(lambda x: TextBlob(x).sentiment.polarity)
n_df['subjectivity'] = n_df['text'].apply(lambda x: TextBlob(x).sentiment.subjectivity)
n_df.head()
# Out:
#    user_verified                 date  \
# 0           True  2021-09-06 23:55:48
# 1          False  2021-09-06 23:46:16
# 2          False  2021-09-06 23:38:34
# 3          False  2021-09-06 23:36:50
# 4          False  2021-09-06 23:29:20
#
#                                                 text  \
# 0              please take covid seriously joke from
# 1  that more than risk from risk from vaccine pos...
# 2                     said anyone supporting blanket
# 3  more crazy this time where medical doctor writ...
# 4                 great point case about should take
#
#                                             hashtags  \
# 0                                                NaN
# 1                                     CovidVaccine
# 2    FascistEmployerMandate    FascistVaccinePass...
# 3                                                NaN
# 4                 CovidVaccine    COVIDVaccination
#
#                                            tokenized  polarity  subjectivity
# 0                 pleas take covid serious joke from -0.333333      0.666667
# 1  that more than risk from risk from vaccin possibl  0.250000      0.750000
# 2                         said anyon support blanket  0.250000      0.250000
# 3  more crazi thi time where medic doctor write mask -0.033333      0.466667
# 4                 great point case about should take  0.800000      0.750000

# %%
def analyze_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(cleaner(tweet))
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %%
# We create a column with the result of the analysis:
n_df['SA'] = np.array([ analyze_sentiment(tweet) for tweet in n_df['text'] ])

# %%
n_df.head()
# Out:
#    user_verified                 date  \
# 0           True  2021-09-06 23:55:48
# 1          False  2021-09-06 23:46:16
# 2          False  2021-09-06 23:38:34
# 3          False  2021-09-06 23:36:50
# 4          False  2021-09-06 23:29:20
#
#                                                 text  \
# 0              please take covid seriously joke from
# 1  that more than risk from risk from vaccine pos...
# 2                     said anyone supporting blanket
# 3  more crazy this time where medical doctor writ...
# 4                 great point case about should take
#
#                                             hashtags  \
# 0                                                NaN
# 1                                     CovidVaccine
# 2    FascistEmployerMandate    FascistVaccinePass...
# 3                                                NaN
# 4                 CovidVaccine    COVIDVaccination
#
#                                            tokenized  polarity  subjectivity  \
# 0                 pleas take covid serious joke from -0.333333      0.666667
# 1  that more than risk from risk from vaccin possibl  0.250000      0.750000
# 2                         said anyon support blanket  0.250000      0.250000
# 3  more crazi thi time where medic doctor write mask -0.033333      0.466667
# 4                 great point case about should take  0.800000      0.750000
#
#    SA
# 0  -1
# 1   1
# 2   1
# 3  -1
# 4   1

# %%
#n_df.to_csv('../Resources/labelled_tweets.csv',index=False)

# %%
neu_words =' '.join([text for text in n_df['text'][n_df['SA'] == 0]])

wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(neu_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
neg_words = ' '.join([text for text in n_df['text'][n_df['SA'] == -1]])
wordcloud = WordCloud(width=800, height=500,
random_state=21, max_font_size=110).generate(neg_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
pos_words = ' '.join([text for text in n_df['text'][n_df['SA'] > 0]])
wordcloud = WordCloud(width=800, height=500,
random_state=21, max_font_size=110).generate(pos_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
import seaborn as sns
a = nltk.FreqDist(pos_words)
d = pd.DataFrame({'Tweet': list(a.keys()),
                  'Count': list(a.values())})
# selecting top 10 most frequent words    
d = d.nlargest(columns="Count", n = 10) 
plt.figure(figsize=(16,5))
ax = sns.barplot(data=d, x= "Tweet", y = "Count")
ax.set(ylabel = 'Positive words Count')
plt.show()

# %%
b = nltk.FreqDist(neg_words)
e = pd.DataFrame({'Tweet': list(b.keys()),
                  'Count': list(b.values())})
# selecting top 10 most frequent words    
e = e.nlargest(columns="Count", n = 10) 
plt.figure(figsize=(16,5))
ax = sns.barplot(data=e, x= "Tweet", y = "Count")
ax.set(ylabel = 'Negative words Count')
plt.show()

# %%
#tweet text cleaning option 2: 
def clean_tweet(temp):
    
    #for temp in range(0, len(n_df)) :
         #if type(temp) == float:
         #    return ""
         #else: 
            #print(temp)
    temp = temp.lower()
    temp = re.sub("'", "", str(temp)) # to avoid removing contractions in english
    temp = re.sub("@[A-Za-z0-9_]+","", str(temp))
    temp = re.sub("#[A-Za-z0-9_]+","", str(temp))
    temp = re.sub(r"www.\S+", "", temp)
    temp = re.sub(r"http\S+", "", temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('\[.*?\]',' ', temp)
    temp = re.sub("[^a-z0-9]"," ", temp)
    temp = temp.split()
    stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]
    temp = [w for w in temp if not w in stopwords]
    temp = " ".join(word for word in temp)
    return temp
n_df['text'] = n_df['text'].map(lambda x: clean_tweet(x))
n_df.head()
# Out:
#    user_verified                 date  \
# 0           True  2021-09-06 23:55:48
# 1          False  2021-09-06 23:46:16
# 2          False  2021-09-06 23:38:34
# 3          False  2021-09-06 23:36:50
# 4          False  2021-09-06 23:29:20
#
#                                                 text  \
# 0                   please take covid seriously joke
# 1          that more than risk risk vaccine possibly
# 2                     said anyone supporting blanket
# 3  more crazy this time where medical doctor writ...
# 4                 great point case about should take
#
#                                             hashtags  \
# 0                                                NaN
# 1                                     CovidVaccine
# 2    FascistEmployerMandate    FascistVaccinePass...
# 3                                                NaN
# 4                 CovidVaccine    COVIDVaccination
#
#                                            tokenized  polarity  subjectivity  \
# 0                 pleas take covid serious joke from -0.333333      0.666667
# 1  that more than risk from risk from vaccin possibl  0.250000      0.750000
# 2                         said anyon support blanket  0.250000      0.250000
# 3  more crazi thi time where medic doctor write mask -0.033333      0.466667
# 4                 great point case about should take  0.800000      0.750000
#
#    SA
# 0  -1
# 1   1
# 2   1
# 3  -1
# 4   1

# %%
#n_df.to_csv('../Resources/cleaned_tweets_train.csv',index=False)

# %%
SentimentText = n_df['text']
SentimentText
# Out:
# 0                        please take covid seriously joke
# 1               that more than risk risk vaccine possibly
# 2                          said anyone supporting blanket
# 3       more crazy this time where medical doctor writ...
# 4                      great point case about should take
#                               ...
# 5674    excellent summary where headed race after ever...
# 5675          sweetening deal through sept will give away
# 5676                                            does work
# 5677    excited soaring together again help stay toget...
# 5678    beth cover vaccine research propaganda hesitat...
# Name: text, Length: 5679, dtype: object

# %%
sentiment_text_list = SentimentText
textfile = open("../Resources/sentiment_text_list.txt", "w")
for element in sentiment_text_list:
    textfile.write(element + "\n")
textfile.close()

# %%
# #lower case
# temp = df['text'].str.lower()
# temp

# %%
#remove the mentions and hashtags 
# temp = re.sub("@[A-Za-z0-9_]+","", str(temp))
# temp = re.sub("#[A-Za-z0-9_]+","", str(temp))
# print(temp)

# %%
#remove links 
# temp = re.sub(r"http\S+", "", temp)
# temp = re.sub(r"www.\S+", "", temp)
# print(temp)

# %%
# #remove punctuations
# temp = re.sub('[()!?]', ' ', temp)
# temp = re.sub('\[.*?\]',' ', temp)
# temp

# %%
# #Filtering non-alphanumeric characters
# temp = re.sub("[^a-z0-9]"," ", temp)
# print(temp)

# %%
# #tokenize 
# temp = temp.split()
# print(temp)

# %%
# #remove stopwords
# stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]
 
# temp = [w for w in temp if not w in stopwords]
# temp = " ".join(word for word in temp)
# print(temp)

# %%
def get_feature_vector(train_fit):
    vector = TfidfVectorizer(sublinear_tf=True)
    vector.fit(train_fit)
    return vector

# %%
def int_to_string(sentiment):
    if sentiment == 0:
        return "Negative"
    elif sentiment == 2:
        return "Neutral"
    else:
        return "Positive"

# %% [markdown]
# *TRAIN WITH LOGISTICS REGRESSION MODEL
#
# *TRAIN WITH NAIVE BAYES MODEL

# %%
#https://github.com/adibyte95/Twittter-sentiment-analysis 

# function to plot confusion matrix
# this function is from sklearn website
# link - http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 3.
    for i, j, k in itertools.product(range(cm.shape[0]), range(cm.shape[1], range(cm.shape[-1]))):
        plt.text(k, j, i, format(cm[i, j, k], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j, k] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#Finding the unigram representation
from sklearn.feature_extraction.text import CountVectorizer
vectorizer=CountVectorizer()

# %%
# loading the cleaned training tweets
# import pickle

# with open('../Resources/sentiment_text_list.txt', 'rb') as f:
#     st = pickle.load(f)

# %%
# fitting the vectorizer
X=vectorizer.fit_transform(SentimentText)
print(X)
# Out:
#   (0, 2795)	1
#   (0, 3675)	1
#   (0, 987)	1
#   (0, 3308)	1
#   (0, 2098)	1
#   (1, 3729)	1
#   (1, 2444)	1
#   (1, 3723)	1
#   (1, 3177)	2
#   (1, 3982)	1
#   (1, 2830)	1
#   (2, 3219)	1
#   (2, 347)	1
#   (2, 3619)	1
#   (2, 539)	1
#   (3, 2444)	1
#   (3, 1021)	1
#   (3, 3751)	1
#   (3, 3774)	1
#   (3, 4107)	1
#   (3, 2364)	1
#   (3, 1249)	1
#   (3, 4173)	1
#   (3, 2341)	1
#   (4, 3675)	1
#   :	:
#   (5675, 4127)	1
#   (5675, 1089)	1
#   (5675, 445)	1
#   (5675, 3766)	1
#   (5675, 3303)	1
#   (5675, 1713)	1
#   (5675, 3653)	1
#   (5676, 1252)	1
#   (5676, 4152)	1
#   (5677, 1834)	1
#   (5677, 271)	1
#   (5677, 1825)	1
#   (5677, 1646)	1
#   (5677, 3787)	2
#   (5677, 3518)	1
#   (5677, 1453)	1
#   (5677, 3422)	1
#   (5678, 3982)	1
#   (5678, 3431)	1
#   (5678, 2732)	1
#   (5678, 3127)	1
#   (5678, 984)	1
#   (5678, 2928)	1
#   (5678, 518)	1
#   (5678, 1840)	1

# %%
# getting the target values i.e wheather the tweets are positive or negative
train_data = pd.read_csv('../Resources/labelled_tweets.csv', encoding = 'ISO-8859-1')
y = train_data['SA']

# %%
y.shape
# Out:
# (5679,)

# %%
X.shape
# Out:
# (5679, 4200)

# %%
# splitting into training and testing set so as to evaluate the classifier
from sklearn.model_selection import train_test_split
X_train, X_test, y_train ,y_test = train_test_split(X,y,train_size = .8 , test_size = .2 , random_state = 0)

# %%
# fitting the multinomial bayes classifier
clf = MultinomialNB()
clf.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
clf.score(X_train,y_train)
# Out:
# 0.9339643407440018

# %%
y_pred = clf.predict(X_test)
# testing score
clf.score(X_test, y_test)
# Out:
# 0.8441901408450704

# %%
# Compute confusion matrix
from sklearn.metrics import confusion_matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=3)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["positive",'neutral' "negative"],
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["positive", 'neutral' "negative"], normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 69  41  17]
#  [ 15 515  25]
#  [ 18  61 375]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-329-052f6a22ea53> in <module>
#       7 plt.figure()
#       8 plot_confusion_matrix(cnf_matrix, classes=["positive",'neutral' "negative"],
# ----> 9                       title='Confusion matrix, without normalization')
#      10
#      11 # Plot normalized confusion matrix
#
# <ipython-input-318-7b4d9b55a029> in plot_confusion_matrix(cm, classes, normalize, title, cmap)
#      27     fmt = '.2f' if normalize else 'd'
#      28     thresh = cm.max() / 3.
# ---> 29     for i, j, k in itertools.product(range(cm.shape[0]), range(cm.shape[1], range(cm.shape[-1]))):
#      30         plt.text(k, j, i, format(cm[i, j, k], fmt),
#      31                  horizontalalignment="center",
#
# NameError: name 'itertools' is not defined

# %%
# Split dataset into Train, Test

# # Same tf vector will be used for Testing sentiments on unseen trending data
# tf_vector = get_feature_vector(np.array(n_df.iloc[:, 1]).ravel())
# X = tf_vector.transform(np.array(n_df.iloc[:, 1]).ravel())
# y = np.array(n_df.iloc[:, 0]).ravel()
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# # Training Naive Bayes model
# NB_model = MultinomialNB()
# NB_model.fit(X_train, y_train)
# y_predict_nb = NB_model.predict(X_test)
# print(f'Naive-Bayes Model:{accuracy_score(y_test, y_predict_nb)}')

# # Training Logistics Regression model
# LR_model = LogisticRegression(solver='lbfgs')
# LR_model.fit(X_train, y_train)
# y_predict_lr = LR_model.predict(X_test)
# print(f'Logistics Regression Model: {accuracy_score(y_test, y_predict_lr)}')
# Out:
# Naive-Bayes Model:0.9128521126760564
# Logistics Regression Model: 0.9128521126760564

# %% [markdown]
# Scraping Twitter data via API Call

# %%
import tweepy as tw
import config
from tqdm import tqdm
import os

# %%
consumer_api_key = config.consumer_key
consumer_api_secret = config.consumer_secret

# %%
auth = tw.OAuthHandler(consumer_api_key, consumer_api_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
search_words = "#covidvaccine -filter:retweets" 

date_since = "2021-09-02"
date_until="2021-09-08"
# Collect tweets
tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since,
              until=date_until     
              ).items(7500)

# %%
tweets_copy = []
for tweet in tqdm(tweets):
    tweets_copy.append(tweet)
# Out:
# 848it [00:19, 42.49it/s]

# %%
print(f"New tweets retrieved: {len(tweets_copy)}")
# Out:
# New tweets retrieved: 848

# %%
tweets_df = pd.DataFrame()
for tweet in tqdm(tweets_copy):
    hashtags = []
    try:
        for hashtag in tweet.entities["hashtags"]:
            hashtags.append(hashtag["text"])
    except:
        pass
    tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name, 
                                               'user_location': tweet.user.location,\
                                               'user_description': tweet.user.description,
                                               'user_created': tweet.user.created_at,
                                               'user_followers': tweet.user.followers_count,
                                               'user_friends': tweet.user.friends_count,
                                               'user_favourites': tweet.user.favourites_count,
                                               'user_verified': tweet.user.verified,
                                               'date': tweet.created_at,
                                               'text': tweet.text, 
                                               'hashtags': [hashtags if hashtags else None],
                                               'source': tweet.source,
                                               'is_retweet': tweet.retweeted}, index=[0]))
# Out:
# 100%|██████████| 848/848 [00:03<00:00, 267.60it/s]

# %%
tweets_df
# Out:
#                    user_name          user_location  \
# 0                      Naomi      Edmonton, Alberta
# 0                Carlos Mock            Chicago, IL
# 0    🌲Tree🌲Hugging Oregonian  Pacific Northwest USA
# 0                Carlos Mock            Chicago, IL
# 0   Anff (no DMs)🌼🌷🇬🇧🏴󠁧󠁢󠁥󠁮󠁧󠁿          Bedfordshire
# ..                       ...                    ...
# 0           Indian Weekender               Auckland
# 0            Limey_In_The_US
# 0                        Amy           Longview, TX
# 0              Roberta Henry             Rogers, AR
# 0           Ethan Cornwill 💉    Melbourne, Victoria
#
#                                      user_description        user_created  \
# 0   Franco-canadienne, nature lover, connection se... 2017-04-27 20:49:09
# 0   Author of The Corner Queen--La Loca de La Esqu... 2009-04-23 22:58:18
# 0   🏳️‍🌈#FriendOfDorothy #LGBTQ #CorgiWhipped #Bui... 2009-10-22 10:11:21
# 0   Author of The Corner Queen--La Loca de La Esqu... 2009-04-23 22:58:18
# 0   52 yr old, widowed, teenage son. Politics, hum... 2018-07-07 18:31:04
# ..                                                ...                 ...
# 0   NZ's #1 and the first weekly newspaper for Kiw... 2009-06-28 06:20:50
# 0                                                     2013-07-03 08:14:02
# 0   I am human, I have my own personal opinion on ... 2021-02-22 14:46:09
# 0   #covidwars | #frontlineER Single mom | ER RN |... 2014-04-28 05:36:13
# 0   22, Gunzel, Graphic Designer, Web Developer De... 2012-01-27 13:02:07
#
#     user_followers  user_friends  user_favourites  user_verified  \
# 0               34           147              392          False
# 0              380            72            63594          False
# 0             6623          7116            68311          False
# 0              380            72            63594          False
# 0            14508         15149           216370          False
# ..             ...           ...              ...            ...
# 0             1373          1005             3138          False
# 0               35           150             1636          False
# 0              242           624             7851          False
# 0               36           202              356          False
# 0              202           123              958          False
#
#                   date                                               text  \
# 0  2021-09-07 23:59:56  Show of hands who had the following medical is...
# 0  2021-09-07 23:59:18  #Florida #doctor says she won’t treat #unvacci...
# 0  2021-09-07 23:57:43  Don't be chicken! Get the vaccine!\n#COVIDvacc...
# 0  2021-09-07 23:57:41  #Idaho moves to start #rationing #medical care...
# 0  2021-09-07 23:47:59  @JohnTShallow @Crosscolin88 @NHS I notice Isra...
# ..                 ...                                                ...
# 0  2021-09-07 01:00:41  In another milestone, India administered more ...
# 0  2021-09-07 00:58:47  @AB81971 @TomiLahren It will be hard to get a ...
# 0  2021-09-07 00:57:45  😳😱🤭WTF DID HE JUST SAY?! #BillGates #vaccinati...
# 0  2021-09-07 00:56:30  Finally off work…but the echos of cries and of...
# 0  2021-09-07 00:56:23  Wait… does #5G give you #COVID19 or does the #...
#
#                                              hashtags               source  \
# 0                                                None   Twitter for iPhone
# 0   [Florida, doctor, unvaccinated, patients, COVI...      Twitter Web App
# 0                        [COVIDvaccine, DeltaVariant]  Twitter for Android
# 0   [Idaho, rationing, medical, COVID19, CovidVacc...      Twitter Web App
# 0                                                None  Twitter for Android
# ..                                                ...                  ...
# 0                                                None               Buffer
# 0                                                None  Twitter for Android
# 0   [BillGates, vaccination, CovidVaccine, NewWorl...   Twitter for iPhone
# 0                                                None   Twitter for iPhone
# 0                         [5G, COVID19, CovidVaccine]   Twitter for iPhone
#
#     is_retweet
# 0        False
# 0        False
# 0        False
# 0        False
# 0        False
# ..         ...
# 0        False
# 0        False
# 0        False
# 0        False
# 0        False
#
# [848 rows x 13 columns]

# %%
#tweets_df.to_csv('../Resources/covid_vaccine_090721.csv',index=False)

# %%
n_tweets_df = tweets_df.drop(columns = ['user_name', 'user_location','user_description','user_created',
                         'user_followers','user_friends','user_favourites','source','is_retweet'], axis = 1)
n_tweets_df.head()
# Out:
#    user_verified                date  \
# 0          False 2021-09-07 23:59:56
# 0          False 2021-09-07 23:59:18
# 0          False 2021-09-07 23:57:43
# 0          False 2021-09-07 23:57:41
# 0          False 2021-09-07 23:47:59
#
#                                                 text  \
# 0  Show of hands who had the following medical is...
# 0  #Florida #doctor says she won’t treat #unvacci...
# 0  Don't be chicken! Get the vaccine!\n#COVIDvacc...
# 0  #Idaho moves to start #rationing #medical care...
# 0  @JohnTShallow @Crosscolin88 @NHS I notice Isra...
#
#                                             hashtags
# 0                                               None
# 0  [Florida, doctor, unvaccinated, patients, COVI...
# 0                       [COVIDvaccine, DeltaVariant]
# 0  [Idaho, rationing, medical, COVID19, CovidVacc...
# 0                                               None

# %%
#regex the hashtags 
#n_df['hashtags'] = n_df['hashtags'].apply(lambda x: re.sub('\[.*?\]',' ', str(x)))
n_tweets_df['hashtags'] = n_tweets_df['hashtags'].str.replace("[^a-zA-Z#]", " ")
n_tweets_df.head()
# Out:
# /Users/jtangesq/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
#    user_verified                date  \
# 0          False 2021-09-07 23:59:56
# 0          False 2021-09-07 23:59:18
# 0          False 2021-09-07 23:57:43
# 0          False 2021-09-07 23:57:41
# 0          False 2021-09-07 23:47:59
#
#                                                 text  hashtags
# 0  Show of hands who had the following medical is...       NaN
# 0  #Florida #doctor says she won’t treat #unvacci...       NaN
# 0  Don't be chicken! Get the vaccine!\n#COVIDvacc...       NaN
# 0  #Idaho moves to start #rationing #medical care...       NaN
# 0  @JohnTShallow @Crosscolin88 @NHS I notice Isra...       NaN

# %%
#remove short words less than three letters 
n_tweets_df['text'] = n_tweets_df['text'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))
#lower case all texts
n_tweets_df['text']=n_tweets_df["text"].str.lower()
n_tweets_df.head()
# Out:
#    user_verified                date  \
# 0          False 2021-09-07 23:59:56
# 0          False 2021-09-07 23:59:18
# 0          False 2021-09-07 23:57:43
# 0          False 2021-09-07 23:57:41
# 0          False 2021-09-07 23:47:59
#
#                                                 text  hashtags
# 0  show hands following medical issues last year:...       NaN
# 0  #florida #doctor says won’t treat #unvaccinate...       NaN
# 0  don't chicken! vaccine! #covidvaccine #deltava...       NaN
# 0  #idaho moves start #rationing #medical care am...       NaN
# 0  @johntshallow @crosscolin88 @nhs notice israel...       NaN

# %%
tokenized_tweets = n_tweets_df['text'].apply(lambda x: x.split())

# %%
stemmer = PorterStemmer()
tokenized_tweets = tokenized_tweets.apply(lambda x: [stemmer.stem(i) for i in x]) # stemming

for i in range(len(tokenized_tweets)):
    tokenized_tweets[i] = ' '.join(tokenized_tweets[i])

n_tweets_df['tokenized']= tokenized_tweets
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-203-e0ae9099bedd> in <module>
#       3
#       4 for i in range(len(tokenized_tweets)):
# ----> 5     tokenized_tweets[i] = ' '.join(tokenized_tweets[i])
#       6
#       7 n_tweets_df['tokenized']= tokenized_tweets
#
# TypeError: sequence item 0: expected str instance, list found

# %%
n_tweets_df['text'] = n_tweets_df['text'].map(lambda x: cleaner(x))
n_tweets_df.head()
# Out:
#    user_verified                date  \
# 0          False 2021-09-07 23:59:56
# 0          False 2021-09-07 23:59:18
# 0          False 2021-09-07 23:57:43
# 0          False 2021-09-07 23:57:41
# 0          False 2021-09-07 23:47:59
#
#                                                 text  hashtags
# 0  show following medical last year : ⁃ polio ⁃ r...       NaN
# 0  doctor won ’ t treat unvaccinated person covid...       NaN
# 0                        don ' t chicken ! vaccine !       NaN
# 0            start medical care amid surge covid19 …       NaN
# 0            notice coming with various rise . the …       NaN

# %%
# Creating text feature
n_tweets_df['text'] = n_tweets_df['text'].map(lambda x: cleaner(x))
test_feature = tf_vector.transform(np.array(n_tweets_df.iloc[:, 1]).ravel())

# Using Logistic Regression model for prediction
test_prediction_lr = LR_model.predict(test_feature)

# Averaging out the hashtags result
test_result_ds = pd.DataFrame({'hashtag': n_tweets_df.hashtags, 'prediction':test_prediction_lr})
test_result = test_result_ds.groupby(['hashtags']).max().reset_index()
test_result.columns = ['hashtags', 'predictions']
test_result.predictions = test_result['predictions'].apply(int_to_string)

print(test_result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-5ff1d43a5269> in <module>
#       1 # Creating text feature
#       2 n_tweets_df['text'] = n_tweets_df['text'].map(lambda x: cleaner(x))
# ----> 3 test_feature = tf_vector.transform(np.array(n_tweets_df.iloc[:, 1]).ravel())
#       4
#       5 # Using Logistic Regression model for prediction
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in transform(self, raw_documents)
#    1872         check_is_fitted(self, msg='The TF-IDF vectorizer is not fitted')
#    1873
# -> 1874         X = super().transform(raw_documents)
#    1875         return self._tfidf.transform(X, copy=False)
#    1876
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in transform(self, raw_documents)
#    1253
#    1254         # use the same matrix-building strategy as fit_transform
# -> 1255         _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#    1256         if self.binary:
#    1257             X.data.fill(1)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1113         for doc in raw_documents:
#    1114             feature_counter = {}
# -> 1115             for feature in analyze(doc):
#    1116                 try:
#    1117                     feature_idx = vocabulary[feature]
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     102     else:
#     103         if preprocessor is not None:
# --> 104             doc = preprocessor(doc)
#     105         if tokenizer is not None:
#     106             doc = tokenizer(doc)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _preprocess(doc, accent_function, lower)
#      67     """
#      68     if lower:
# ---> 69         doc = doc.lower()
#      70     if accent_function is not None:
#      71         doc = accent_function(doc)
#
# AttributeError: 'numpy.datetime64' object has no attribute 'lower'
